# %% [markdown]
# ### Importing the Libraries

# %%
# lets import the basic Libraries
import numpy as np
import pandas as pd
import pandas_profiling as profile
import dabl

# for data visualizations
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly

# for interactivity in the notebook
import ipywidgets as widgets
from ipywidgets import interact
from ipywidgets import interact_manual

# %% [markdown]
# ### Reading the Dataset

# %%
# lets import the data
df = pd.read_csv('tarifftruck1.csv')

# %% [markdown]
# ### Inspecting the Data

# %%
# shape of the data
df.shape
# Out:
# (289, 11)

# %%
# columns of the data
df.columns
# Out:
# Index(['year', 'road', 'seasonalimpact', 'demand', 'wttons', 'labour', 'toll',
#        'distance', 'fuelcost', 'miscellaneous', 'tariff'],
#       dtype='object')

# %%
# information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 11 columns):
# year              289 non-null int64
# road              234 non-null object
# seasonalimpact    243 non-null object
# demand            258 non-null object
# wttons            288 non-null float64
# labour            289 non-null int64
# toll              289 non-null int64
# distance          285 non-null float64
# fuelcost          289 non-null int64
# miscellaneous     287 non-null float64
# tariff            289 non-null int64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 25.0+ KB

# %%
# data types of the data
df.dtypes
# Out:
# year                int64
# road               object
# seasonalimpact     object
# demand             object
# wttons            float64
# labour              int64
# toll                int64
# distance          float64
# fuelcost            int64
# miscellaneous     float64
# tariff              int64
# dtype: object

# %%
dabl.plot(df, target_col="tariff", color = 'red')
# Out:
# Target looks like regression

# %% [markdown]
# ### Profile Report of the Data

# %%
# lets change the name of the datset and 
data = df

# %%
# lets check the profule of the data
profile.ProfileReport(data)
# Out:
# Tab(children=(HTML(value='<div id="overview-content" class="row variable spacing">\n    <div class="row">\n   …
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %% [markdown]
# ### Dynamic of the Dataset

# %%
# lets check the head of the data
data.head()
# Out:
#    year road seasonalimpact demand  wttons  labour  toll  distance  fuelcost  \
# 0  2013   nh            yes   high    10.0     750  8200    1460.0     23534
# 1  2013   nh            yes   high    14.8    1110  8600    1360.0     22184
# 2  2013   nh            yes   high    12.0     900  8300    1310.0     21476
# 3  2013   nh            yes   high    10.0     750  2400     650.0     10473
# 4  2013   nh            yes   high     8.0     600  3500     560.0      9417
#
#    miscellaneous  tariff
# 0         9000.0   17950
# 1        10000.0   19710
# 2         9400.0   18600
# 3         6000.0    9150
# 4         5600.0    9700

# %%
# lets check the tail of the data
data.tail()
# Out:
#      year road seasonalimpact  demand  wttons  labour  toll  distance  \
# 284  2015   sh            yes     NaN     4.0     440     0      79.0
# 285  2015  NaN            yes  normal    10.0     900  1360       NaN
# 286  2015  NaN            yes  normal    11.2    1008  1895       NaN
# 287  2015   nh            yes     NaN    18.0    1620  3095       NaN
# 288  2015   nh            yes     NaN    13.6    1224  3120       NaN
#
#      fuelcost  miscellaneous  tariff
# 284      1592         6600.0    7040
# 285      6002         7500.0    9760
# 286      7541         7800.0   10703
# 287     14492         9500.0   14215
# 288     14778         8400.0   12744

# %%
# lets check the sample of the data
data.sample(3)
# Out:
#      year road seasonalimpact  demand  wttons  labour  toll  distance  \
# 140  2014   nh            yes  normal   14.96    1197  2680     365.0
# 46   2013   nh            yes  normal   11.40     798  1980     403.0
# 101  2013   nh            yes  normal    7.80     546   855     246.0
#
#      fuelcost  miscellaneous  tariff
# 140      6942         7566.0   11443
# 46       6574         5780.0    8558
# 101      4086         5060.0    6461

# %% [markdown]
# ## Inferential Statistics

# %%
x = data.describe()
x.style.bar(color = ['silver', 'gold'], align = 'mid')
# Out:
# <style  type="text/css" >
#     #T_c9220106_5205_11ea_b53d_507b9d42aeb2row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 14.3%, transparent 14.3%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 43.6%, transparent 43.6%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 9.6%, transparent 9.6%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 1.5%, transparent 1.5%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 1.9%, transparent 1.9%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.6%, transparent 0.6%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 2.1%, transparent 2.1%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.9%, transparent 0.9%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 99.9%, transparent 99.9%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 2.1%, transparent 2.1%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 30.3%, transparent 30.3%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 13.8%, transparent 13.8%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 4.1%, transparent 4.1%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 22.2%, transparent 22.2%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 51.3%, transparent 51.3%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 32.8%, transparent 32.8%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 5.8%, transparent 5.8%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 12.1%, transparent 12.1%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 14.4%, transparent 14.4%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 6.4%, transparent 6.4%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 16.3%, transparent 16.3%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 13.7%, transparent 13.7%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 14.0%, transparent 14.0%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 99.9%, transparent 99.9%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.6%, transparent 0.6%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row3_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row3_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.3%, transparent 0.3%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 2.1%, transparent 2.1%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 29.9%, transparent 29.9%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row3_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.2%, transparent 0.2%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 99.9%, transparent 99.9%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 1.3%, transparent 1.3%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 21.0%, transparent 21.0%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 2.8%, transparent 2.8%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 1.5%, transparent 1.5%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 8.8%, transparent 8.8%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 40.9%, transparent 40.9%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row4_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 23.0%, transparent 23.0%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 100.0%, transparent 100.0%);
#         }    #T_c9220106_5205_11ea_b53d_507b9d42aeb2row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:

# %%
x = data.cov()
x.style.bar(color = ['silver', 'gold'], align = 'mid')
# Out:
# <style  type="text/css" >
#     #T_c95cab40_5205_11ea_a106_507b9d42aeb2row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.2%, gold 37.2%, gold 37.3%, transparent 37.3%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 54.0%, gold 54.0%, gold 54.0%, transparent 54.0%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.1%, gold 0.1%, gold 0.1%, transparent 0.1%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 0.0%, transparent 0.0%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 0.0%, transparent 0.0%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 0.0%, transparent 0.0%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 0.0%, transparent 0.0%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.2%, gold 37.2%, gold 37.6%, transparent 37.6%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 54.0%, gold 54.0%, gold 60.9%, transparent 60.9%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 0.1%, transparent 0.1%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, silver 0.0%, silver 0.0%, transparent 0.0%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 0.1%, transparent 0.1%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 0.0%, transparent 0.0%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.1%, transparent 0.1%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 0.0%, transparent 0.0%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.2%, gold 37.2%, gold 45.4%, transparent 45.4%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.9%, silver 49.9%, silver 54.0%, transparent 54.0%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.1%, gold 0.1%, gold 9.9%, transparent 9.9%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 2.5%, transparent 2.5%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 6.3%, transparent 6.3%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 2.5%, transparent 2.5%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 5.2%, transparent 5.2%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 3.7%, transparent 3.7%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 37.2%, transparent 37.2%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 53.6%, silver 53.6%, silver 54.0%, transparent 54.0%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.1%, gold 0.1%, gold 33.2%, transparent 33.2%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 42.6%, transparent 42.6%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 33.1%, transparent 33.1%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 33.5%, transparent 33.5%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 33.1%, transparent 33.1%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row3_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 39.1%, transparent 39.1%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 33.9%, silver 33.9%, silver 37.2%, transparent 37.2%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 54.0%, gold 54.0%, gold 68.1%, transparent 68.1%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.1%, gold 0.1%, gold 13.0%, transparent 13.0%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 5.1%, transparent 5.1%);
#         }    #T_c95cab40_5205_11ea_a106_507b9d42aeb2row4_col4 {
#             width:  10em;
#              height:  80%;
#             background

# %%
x = data.corr()
x.style.bar(color = ['silver', 'gold'], align = 'mid')
# Out:
# <style  type="text/css" >
#     #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 10.3%, gold 10.3%, gold 100.0%, transparent 100.0%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.3%, gold 6.3%, gold 14.4%, transparent 14.4%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.9%, gold 5.9%, gold 23.8%, transparent 23.8%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 10.3%, transparent 10.3%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 2.9%, transparent 2.9%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 2.4%, transparent 2.4%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 28.1%, transparent 28.1%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.3%, gold 6.3%, gold 11.1%, transparent 11.1%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 10.3%, gold 10.3%, gold 18.0%, transparent 18.0%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.3%, gold 6.3%, gold 100.0%, transparent 100.0%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 5.9%, transparent 5.9%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 10.2%, silver 10.2%, silver 10.3%, transparent 10.3%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.9%, gold 2.9%, gold 11.1%, transparent 11.1%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.4%, gold 2.4%, gold 5.9%, transparent 5.9%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 70.5%, transparent 70.5%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 6.3%, transparent 6.3%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 10.3%, gold 10.3%, gold 27.3%, transparent 27.3%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.4%, silver 0.4%, silver 6.3%, transparent 6.3%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.9%, gold 5.9%, gold 100.0%, transparent 100.0%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 10.3%, gold 10.3%, gold 50.3%, transparent 50.3%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.9%, gold 2.9%, gold 52.9%, transparent 52.9%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.4%, gold 2.4%, gold 52.0%, transparent 52.0%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 81.9%, transparent 81.9%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.3%, gold 6.3%, gold 67.5%, transparent 67.5%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 10.3%, transparent 10.3%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.2%, silver 6.2%, silver 6.3%, transparent 6.3%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.9%, gold 5.9%, gold 47.9%, transparent 47.9%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 10.3%, gold 10.3%, gold 100.0%, transparent 100.0%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.9%, gold 2.9%, gold 37.2%, transparent 37.2%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.4%, gold 2.4%, gold 88.9%, transparent 88.9%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 63.9%, transparent 63.9%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row3_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.3%, gold 6.3%, gold 92.7%, transparent 92.7%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 7.6%, silver 7.6%, silver 10.3%, transparent 10.3%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.3%, gold 6.3%, gold 14.2%, transparent 14.2%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.9%, gold 5.9%, gold 54.3%, transparent 54.3%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 10.3%, gold 10.3%, gold 42.0%, transparent 42.0%);
#         }    #T_c992bc5c_5205_11ea_b82a_507b9d42aeb2row4_col4 {
#             width:  10em;
#              height:

# %%
# lets check the missing values present in the data
x = data.isnull().sum()
x = pd.DataFrame(x)
x.style.bar(color = ['lightgreen'], align = 'mid')
# Out:
# <style  type="text/css" >
#     #T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row0_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }    #T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row2_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 56.4%, transparent 56.4%);
#         }    #T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 1.8%, transparent 1.8%);
#         }    #T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row5_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row6_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 7.3%, transparent 7.3%);
#         }    #T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row8_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 3.6%, transparent 3.6%);
#         }    #T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row10_col0 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2level0_row0" class="row_heading level0 row0" >year</th>
#                         <td id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row0_col0" class="data row0 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2level0_row1" class="row_heading level0 row1" >road</th>
#                         <td id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row1_col0" class="data row1 col0" >55</td>
#             </tr>
#             <tr>
#                         <th id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2level0_row2" class="row_heading level0 row2" >seasonalimpact</th>
#                         <td id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row2_col0" class="data row2 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2level0_row3" class="row_heading level0 row3" >demand</th>
#                         <td id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row3_col0" class="data row3 col0" >31</td>
#             </tr>
#             <tr>
#                         <th id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2level0_row4" class="row_heading level0 row4" >wttons</th>
#                         <td id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row4_col0" class="data row4 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2level0_row5" class="row_heading level0 row5" >labour</th>
#                         <td id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row5_col0" class="data row5 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2level0_row6" class="row_heading level0 row6" >toll</th>
#                         <td id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row6_col0" class="data row6 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2level0_row7" class="row_heading level0 row7" >distance</th>
#                         <td id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row7_col0" class="data row7 col0" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2level0_row8" class="row_heading level0 row8" >fuelcost</th>
#                         <td id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row8_col0" class="data row8 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2level0_row9" class="row_heading level0 row9" >miscellaneous</th>
#                         <td id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row9_col0" class="data row9 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2level0_row10" class="row_heading level0 row10" >tariff</th>
#                         <td id="T_87ea8e7e_5789_11ea_a01a_507b9d42aeb2row10_col0" class="data row10 col0" >0</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Data Visualization

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
# lets check the columns again
data.columns
# Out:
# Index(['year', 'road', 'seasonalimpact', 'demand', 'wttons', 'labour', 'toll',
#        'distance', 'fuelcost', 'miscellaneous', 'tariff'],
#       dtype='object')

# %%
plt.rcParams['figure.figsize'] = (11, 6)
plt.style.use('seaborn-dark')

sns.scatterplot(data['miscellaneous'],data['tariff'],  color = 'red')
plt.title('Distance vs Fuel Cost', fontsize = 20)
plt.show()

# %%
# lets compare the toll and tariff rate

plt.rcParams['figure.figsize'] = (11, 6)
plt.style.use('dark_background')

sns.lineplot(data['distance'],data['fuelcost'],  color = 'red')
plt.title('Distance vs Fuel Cost', fontsize = 20)
plt.show()

# %%
# lets compare the toll and tariff rate

plt.rcParams['figure.figsize'] = (11, 6)
plt.style.use('ggplot')

sns.lineplot(data['year'],data['tariff'],  color = 'red')
plt.title('Tariff Rate Year wise Growth Trend', fontsize = 20)
plt.show()

# %%
# lets compare the toll and tariff rate

plt.rcParams['figure.figsize'] = (11, 6)
plt.style.use('seaborn-dark')

sns.scatterplot(data['tariff'], data['toll'], color = 'red')
plt.title('Tariff Rate Year wise Growth Trend', fontsize = 20)
plt.show()

# %%
# lets check the yearly growth in wttons

plt.rcParams['figure.figsize'] = (11, 6)
plt.style.use('seaborn-dark')

sns.boxenplot(data['year'], data['wttons'], color = 'purple')
plt.title('Tariff Rate Year wise Growth Trend', fontsize = 20)
plt.show()

# %%
# lets check the tariff rate year wise

plt.rcParams['figure.figsize'] = (11, 6)
plt.style.use('seaborn-dark')

sns.lineplot(data['year'], data['tariff'], color = 'purple')
plt.title('Tariff Rate Year wise Growth Trend', fontsize = 20)
plt.show()

# %%
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (11, 7)

sns.countplot(data['demand'], palette = 'copper')
plt.title('Pie Chart Representing Different Seasonal Impacts on Tariff Rate', fontsize = 20)
plt.xlabel('Demand')
plt.ylabel(' ')

plt.show()

# %%
plt.style.use('seaborn-darkgrid')
plt.rcParams['figure.figsize'] = (7, 7)

data['seasonalimpact'].value_counts().plot(kind = 'pie',
                                          colors = ['lightgreen','gold','silver'])
plt.title('Pie Chart Representing Different Seasonal Impacts on Tariff Rate', fontsize = 20)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Interactive Analysis

# %%
# lets check correlations

@interact
def check_correlation(column1 = list(data.select_dtypes('number').columns),
                      column2 = list(data.select_dtypes('number').columns[1:])):
    print(f"The Correlation is :", {data[column1].corr(data[column2])})
# Out:
# interactive(children=(Dropdown(description='column1', options=('year', 'wttons', 'labour', 'toll', 'distance',…

# %%
# lets check the covariances

@interact
def check_covariance(column1 = list(data.select_dtypes('number').columns),
                      column2 = list(data.select_dtypes('number').columns[1:])):
    print(f"The Covariance is :", {data[column1].cov(data[column2])})
# Out:
# interactive(children=(Dropdown(description='column1', options=('year', 'wttons', 'labour', 'toll', 'distance',…

# %%
# lets check the Maximum Values in each of the Columns

@interact
def check_maximum(column1 = list(data.select_dtypes('number').columns)):
    print(f"The Maximum Value is :", {data[column1].max()})
# Out:
# interactive(children=(Dropdown(description='column1', options=('year', 'wttons', 'labour', 'toll', 'distance',…

# %%
# lets check the Minimum Values in each of the Columns

@interact
def check_minimum(column1 = list(data.select_dtypes('number').columns)):
    print(f"The Minimum Value is :", {data[column1].min()})
# Out:
# interactive(children=(Dropdown(description='column1', options=('year', 'wttons', 'labour', 'toll', 'distance',…

# %%
# lets check the Standard Deviation in each of the Columns

@interact
def check_deviation(column1 = list(data.select_dtypes('number').columns)):
    print(f"The Standard Deviation is :", {data[column1].std()})
# Out:
# interactive(children=(Dropdown(description='column1', options=('year', 'wttons', 'labour', 'toll', 'distance',…

# %%
plt.rcParams['figure.figsize'] = (11, 7)

# %%
# lets check the scatter plots
plt.style.use('dark_background')

@interact_manual
def scatter_plot(column1 = list(data.select_dtypes('number').columns),
                column2 = list(data.select_dtypes('number').columns[1:])):
    data.plot(kind = 'scatter',
              color = 'white',
              x = column1,
              y = column2)
# Out:
# interactive(children=(Dropdown(description='column1', options=('year', 'wttons', 'labour', 'toll', 'distance',…

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
plt.style.use('ggplot')

@interact_manual
def scatter_plot(column1 = list(data.select_dtypes('number').columns),
                column2 = list(data.select_dtypes('number').columns[1:]),
                kind = ['scatter','line']):
    data.plot(kind = kind,
              color = 'black',
              x = column1,
              y = column2)
# Out:
# interactive(children=(Dropdown(description='column1', options=('year', 'wttons', 'labour', 'toll', 'distance',…

# %%
@interact_manual
def scatter_plot(column1 = list(data.select_dtypes('number').columns),
                column2 = list(data.select_dtypes('number').columns[1:]),
                kind = ['scatter','line'],
                color = ['black','red','green','yellow','pink']):
    data.plot(kind = kind,
              color = color,
              x = column1,
              y = column2)
# Out:
# interactive(children=(Dropdown(description='column1', options=('year', 'wttons', 'labour', 'toll', 'distance',…

# %%
@interact_manual
def scatter_plot(column1 = list(data.select_dtypes('object').columns),
                column2 = list(data.select_dtypes('number').columns[1:]),
                 palette = ['copper','spring','summer','Reds','Greens','Blues']):
    sns.boxenplot(
              data[column1],
              data[column2],
              palette = palette)
# Out:
# interactive(children=(Dropdown(description='column1', options=('road', 'seasonalimpact', 'demand'), value='roa…

# %% [markdown]
# ## Variable Analysis

# %%
data.columns
# Out:
# Index(['year', 'road', 'seasonalimpact', 'demand', 'wttons', 'labour', 'toll',
#        'distance', 'fuelcost', 'miscellaneous', 'tariff'],
#       dtype='object')

# %%
sns.distplot(data['tariff'],
             color = 'black')
plt.title('Distribution of Tariff Rates', fontsize = 20)
plt.show()

# %%
sns.distplot(data['fuelcost'],
             color = 'red')
plt.title('Distribution of Fuel Cost', fontsize = 20)
plt.show()

# %%
sns.distplot(data['distance'],
             color = 'pink')
plt.title('Distribution of Distances Travelled', fontsize = 20)
plt.show()

# %%
sns.distplot(data['toll'],
             color = 'blue')
plt.title('Distribution of Toll Charges', fontsize = 20)
plt.show()

# %%
sns.distplot(data['labour'],
             color = 'yellow')
plt.title('Distribution of Labor Charges', fontsize = 20)
plt.show()

# %%
# lets do bi variate analysis

d1 = pd.crosstab(data['year'], data['seasonalimpact'],)
d1
# Out:
# seasonalimpact  high  no  yes
# year
# 2013               0  24   94
# 2014               0  42   79
# 2015               1  11   38

# %%
# lets plot the above data

d1.plot(kind = 'bar',
        stacked = False,
        color = ['silver', 'gold'])
plt.title('Seasonal Impact each Year', fontsize = 20)
plt.show()

# %%
# demand vs year

d2 = pd.crosstab(data['year'], data['demand'],)
d2
# Out:
# demand  6  high  less  low  normal
# year
# 2013    0    28    33    0      46
# 2014    0    45    23    0      37
# 2015    1    21     0    8      16

# %%
# lets plot the above data

d2.plot(kind = 'bar',
        color = ['pink', 'gold','crimson','lightgreen','silver'],)
plt.title('Demand each year', fontsize = 20)
plt.show()

# %%
# heatmap for correlation

plt.rcParams['figure.figsize'] = (12, 7)
sns.heatmap(data.corr(),
            cmap = 'Blues',
            annot = True)
plt.title('Heatmap for Correlation', fontsize = 20)
plt.show()

# %%
# heatmap for covariance

sns.heatmap(data.cov(),
            cmap = 'copper',
            annot = True)
plt.title('Covariance of the Data', fontsize = 20)
plt.show()

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### Imputing Missing Values

# %%
# lets check the mean value of wttons as it of integer type
data['wttons'].mean()
# Out:
# 13.630694444444444

# %%
# lets impute that one missing value with the median value instead of mean value 
data['wttons'] = data['wttons'].fillna(data['wttons'].mean())
print("Medain Value of wttons: ", data['wttons'].median())
print("Mean Value of wttons: ", data['wttons'].mean())
# Out:
# Medain Value of wttons:  11.0
# Mean Value of wttons:  13.630694444444444

# %%
# lets check the values in the demand column
data['demand'].value_counts()
# Out:
# normal    99
# high      94
# less      56
# low        8
# 6          1
# Name: demand, dtype: int64

# %%
# lets use the mode values to impute the demand column
data['demand'] = data['demand'].fillna(data['demand'].mode()[0])
data['demand'].value_counts()
# Out:
# normal    130
# high       94
# less       56
# low         8
# 6           1
# Name: demand, dtype: int64

# %%
# lets check the values in the seasonal impact column
data['seasonalimpact'].value_counts()
# Out:
# yes     165
# no       77
# high      1
# Name: seasonalimpact, dtype: int64

# %%
# lets use the mode values to impute the seasonal impact column
data['seasonalimpact'] = data['seasonalimpact'].fillna(data['seasonalimpact'].mode()[0])
data['seasonalimpact'].value_counts()
# Out:
# yes     211
# no       77
# high      1
# Name: seasonalimpact, dtype: int64

# %%
# lets check the values in the road column
data['road'].value_counts()
# Out:
# nh     184
# sh      49
# yes      1
# Name: road, dtype: int64

# %%
# lets use the mode values to impute the vmissing values in the road columns
data['road'] = data['road'].fillna(data['road'].mode()[0])
data['road'].value_counts()
# Out:
# nh     239
# sh      49
# yes      1
# Name: road, dtype: int64

# %%
# lets check the values in the distance column
data['distance'].median()
# Out:
# 456.0

# %%
# lets  impute the missing values with the median values
data['distance'] = data['distance'].fillna(data['distance'].median())

# %%
# lets check the values in the road column
data['miscellaneous'].median()
# Out:
# 6780.0

# %%
# lets  impute the missing values with the median values
data['miscellaneous'] = data['miscellaneous'].fillna(data['miscellaneous'].median())

# %%
# as we have imputed all the missing values now lets check how many missing values are left
data.isnull().sum()
# Out:
# year              0
# road              0
# seasonalimpact    0
# demand            0
# wttons            0
# labour            0
# toll              0
# distance          0
# fuelcost          0
# miscellaneous     0
# tariff            0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# #### Encoding Varibles

# %%
# encoding of the Variables
# lets check how many categorical variables are present in the columns

x = data.dtypes =='object'
x = x[x == True]
x.index
# Out:
# Index(['road', 'seasonalimpact', 'demand'], dtype='object')

# %%
# lets check the values of demand

data['demand'].value_counts()
# Out:
# normal    130
# high       94
# less       56
# low         8
# 6           1
# Name: demand, dtype: int64

# %%
# lets check the effect of these values with the target variable

data[['demand', 'tariff']].groupby(['demand']).agg('median')
# Out:
#          tariff
# demand
# 6          77.0
# high    11250.5
# less     8202.0
# low     10516.0
# normal   8579.0

# %%
data['demand'] = data['demand'].replace(6, -1)
data['demand'] = data['demand'].replace('high', 2)
data['demand'] = data['demand'].replace('low', 2)
data['demand'] = data['demand'].replace('normal', 1)
data['demand'] = data['demand'].replace('less', 1)

# %%
# lets check the values of seasonal impact

data['seasonalimpact'].value_counts()
# Out:
# yes     211
# no       77
# high      1
# Name: seasonalimpact, dtype: int64

# %%
# lets check the effect of these values with the target variable

data[['seasonalimpact', 'tariff']].groupby(['seasonalimpact']).agg('median')
# Out:
#                 tariff
# seasonalimpact
# high                77
# no                9507
# yes               9370

# %%
# lets check the effect of these values with the target variable

data[['seasonalimpact', 'tariff']].groupby(['seasonalimpact']).agg('std')
# Out:
#                      tariff
# seasonalimpact
# high                    NaN
# no              4649.281079
# yes             4404.222390

# %%
# lets replace  these values

data['seasonalimpact'] = data['seasonalimpact'].replace('yes', 1)
data['seasonalimpact'] = data['seasonalimpact'].replace('no', 1)
data['seasonalimpact'] = data['seasonalimpact'].replace('high', 0)

# %%
# lets check the values of road

data['road'].value_counts()
# Out:
# nh     239
# sh      49
# yes      1
# Name: road, dtype: int64

# %%
# lets check the effect of these values with the target variable

data[['road', 'tariff']].groupby(['road']).agg('median')
# Out:
#       tariff
# road
# nh     10128
# sh      6400
# yes       77

# %%
# lets do label encoding

data['road'] = data['road'].replace('nh', 2)
data['road'] = data['road'].replace('sh', 1)
data['road'] = data['road'].replace('yes', 0)

# %%
# lets check the values in the road column

data['road'].value_counts()
# Out:
# 2    239
# 1     49
# 0      1
# Name: road, dtype: int64

# %%
# as we have encoded all the variables lets check how many are objects

data.dtypes
# Out:
# year                int64
# road                int64
# seasonalimpact      int64
# demand             object
# wttons            float64
# labour              int64
# toll                int64
# distance          float64
# fuelcost            int64
# miscellaneous     float64
# tariff              int64
# dtype: object

# %% [markdown]
# ### Data Preparation

# %%
# we know that our target variable is the tariff rate
# lets make it separate

x = data.iloc[:, :-1]
y = data.iloc[:, -1]

# lets check the shape of x and y
print("shape of x :", x.shape)
print("Shape of y :", y.shape)
# Out:
# shape of x : (289, 10)
# Shape of y : (289,)

# %%
# lets visualize x and y
x.head()
# Out:
#    year  road  seasonalimpact demand  wttons  labour  toll  distance  \
# 0  2013     2               1      2    10.0     750  8200    1460.0
# 1  2013     2               1      2    14.8    1110  8600    1360.0
# 2  2013     2               1      2    12.0     900  8300    1310.0
# 3  2013     2               1      2    10.0     750  2400     650.0
# 4  2013     2               1      2     8.0     600  3500     560.0
#
#    fuelcost  miscellaneous
# 0     23534         9000.0
# 1     22184        10000.0
# 2     21476         9400.0
# 3     10473         6000.0
# 4      9417         5600.0

# %%
y.head()
# Out:
# 0    17950
# 1    19710
# 2    18600
# 3     9150
# 4     9700
# Name: tariff, dtype: int64

# %%
# lets split these dependent and independent variables into train and test sets

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, 
                                                    y, 
                                                    test_size = 0.2,
                                                    random_state = 0)

# lets check the shape of the training nad testing sets of dependent and independent variables
print("Shape of x_train :", x_train.shape)
print("Shape of x_test :", x_test.shape)
print("Shape of y_train :", y_train.shape)
print("Shape of y_test :", y_test.shape)
# Out:
# Shape of x_train : (231, 10)
# Shape of x_test : (58, 10)
# Shape of y_train : (231,)
# Shape of y_test : (58,)

# %%
# lets check our x_train and other sets

x_train.head()
# Out:
#      year  road  seasonalimpact demand  wttons  labour  toll  distance  \
# 46   2013     2               1      1    11.4     798  1980     403.0
# 259  2015     2               1      1    12.0    1080  2160     558.0
# 216  2014     2               1      1    12.0     960  2340     542.3
# 168  2014     2               1      2    10.6     954  4600     761.0
# 225  2014     2               1      1     7.8     546  1560     275.0
#
#      fuelcost  miscellaneous
# 46       6574         5780.0
# 259     11094         8000.0
# 216     10276         7500.0
# 168     14773         7185.0
# 225      5212         5355.0

# %%
x_train.style.bar(color = ['red','green'], align = 'zero')
# Out:
# <style  type="text/css" >
#     #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 100.0%, transparent 100.0%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 100.0%, transparent 100.0%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 100.0%, transparent 100.0%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 77.1%, transparent 77.1%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 63.3%, transparent 63.3%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 58.5%, transparent 58.5%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 51.4%, transparent 51.4%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row0_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 59.8%, transparent 59.8%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row0_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 70.9%, transparent 70.9%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 100.0%, transparent 100.0%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 100.0%, transparent 100.0%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 100.0%, transparent 100.0%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 78.6%, transparent 78.6%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 68.0%, transparent 68.0%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 59.3%, transparent 59.3%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 51.9%, transparent 51.9%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row1_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 66.6%, transparent 66.6%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row1_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 79.0%, transparent 79.0%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 100.0%, transparent 100.0%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 100.0%, transparent 100.0%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 100.0%, transparent 100.0%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 78.6%, transparent 78.6%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 66.0%, transparent 66.0%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 60.1%, transparent 60.1%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 51.9%, transparent 51.9%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row2_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 65.4%, transparent 65.4%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row2_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 77.2%, transparent 77.2%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 100.0%, transparent 100.0%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 100.0%, transparent 100.0%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 100.0%, transparent 100.0%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 75.2%, transparent 75.2%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 65.9%, transparent 65.9%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 69.8%, transparent 69.8%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row3_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 52.6%, transparent 52.6%);
#         }    #T_caeb310a_57f4_11ea_9b62_507b9d42aeb2row3_col8 {
#             width:  10em;
#              height:  80%;
#             background

# %%
x_test.head()
# Out:
#      year  road  seasonalimpact demand  wttons  labour  toll  distance  \
# 55   2013     2               1      1    11.8     826  1545     240.0
# 182  2014     1               1      1    11.0     880     0     179.0
# 92   2013     2               1      1    11.0     770  2900     329.0
# 209  2014     2               1      2    12.0    1080  3400     586.0
# 261  2015     2               1      1     8.8     792  1740     274.0
#
#      fuelcost  miscellaneous
# 55       3934         5860.0
# 182      3526         6675.0
# 92       5326         5700.0
# 209     10928         7500.0
# 261      5455         7200.0

# %%
y_train.head()
# Out:
# 46      8558
# 259    11240
# 216    10800
# 168    12739
# 225     7461
# Name: tariff, dtype: int64

# %%
y_test.head()
# Out:
# 55      8231
# 182     7555
# 92      9370
# 209    11980
# 261     9732
# Name: tariff, dtype: int64

# %% [markdown]
# ### Feature Scaling

# %%
# lets do standardization of the data to get better results

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# lets check the shape of sets
print("Shape of x_train :", x_train.shape)
print("Shape of x_test :", x_test.shape)
# Out:
# Shape of x_train : (231, 10)
# Shape of x_test : (58, 10)

# %%
x_train_viz = pd.DataFrame(x_train)
x_train_viz.style.bar(color = ['red','green'], align = 'mid')
# Out:
# <style  type="text/css" >
#     #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 37.9%, transparent 37.9%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 82.3%, green 82.3%, green 100.0%, transparent 100.0%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row0_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 35.1%, transparent 35.1%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.5%, red 43.5%, red 44.1%, transparent 44.1%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 17.8%, red 17.8%, red 22.4%, transparent 22.4%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 17.1%, red 17.1%, red 22.2%, transparent 22.2%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.4%, red 2.4%, red 3.8%, transparent 3.8%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row0_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 17.3%, red 17.3%, red 27.4%, transparent 27.4%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row0_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 16.5%, red 16.5%, red 30.0%, transparent 30.0%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.9%, green 37.9%, green 100.0%, transparent 100.0%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 82.3%, green 82.3%, green 100.0%, transparent 100.0%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row1_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 35.1%, transparent 35.1%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.1%, green 44.1%, green 47.1%, transparent 47.1%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 22.4%, green 22.4%, green 28.4%, transparent 28.4%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 18.6%, red 18.6%, red 22.2%, transparent 22.2%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 3.5%, red 3.5%, red 3.8%, transparent 3.8%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row1_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 27.4%, green 27.4%, green 31.2%, transparent 31.2%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row1_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 30.0%, green 30.0%, green 39.6%, transparent 39.6%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.9%, green 37.9%, green 50.0%, transparent 50.0%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 82.3%, green 82.3%, green 100.0%, transparent 100.0%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row2_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 35.1%, transparent 35.1%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.1%, green 44.1%, green 47.1%, transparent 47.1%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 22.4%, green 22.4%, green 23.9%, transparent 23.9%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 20.2%, red 20.2%, red 22.2%, transparent 22.2%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 3.4%, red 3.4%, red 3.8%, transparent 3.8%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row2_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 27.4%, green 27.4%, green 28.7%, transparent 28.7%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row2_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 30.0%, green 30.0%, green 34.4%, transparent 34.4%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.9%, green 37.9%, green 50.0%, transparent 50.0%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 82.3%, green 82.3%, green 100.0%, transparent 100.0%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row3_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 35.1%, green 35.1%, green 100.0%, transparent 100.0%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.8%, red 38.8%, red 44.1%, transparent 44.1%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 22.4%, green 22.4%, green 23.7%, transparent 23.7%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 22.2%, green 22.2%, green 39.7%, transparent 39.7%);
#         }    #T_d00f6346_57f4_11ea_b3a5_507b9d42aeb2row3_col7 {
#             width:  10em;
#              height

# %%
x_test_viz = pd.DataFrame(x_test)
x_test_viz.style.bar(color = ['red','green'], align = 'mid')
# Out:
# <style  type="text/css" >
#     #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 37.9%, transparent 37.9%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 91.1%, green 91.1%, green 100.0%, transparent 100.0%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row0_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 7.0%, transparent 7.0%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 1.0%, green 1.0%, green 1.0%, transparent 1.0%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 53.6%, red 53.6%, red 59.7%, transparent 59.7%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 8.1%, red 8.1%, red 13.5%, transparent 13.5%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.1%, red 6.1%, red 19.8%, transparent 19.8%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row0_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.9%, red 5.9%, red 19.7%, transparent 19.7%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row0_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 21.7%, red 21.7%, red 36.8%, transparent 36.8%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.9%, green 37.9%, green 50.0%, transparent 50.0%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, red 50.0%, red 91.1%, transparent 91.1%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row1_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 7.0%, transparent 7.0%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.9%, red 0.9%, red 1.0%, transparent 1.0%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 57.1%, red 57.1%, red 59.7%, transparent 59.7%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 13.5%, transparent 13.5%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 3.8%, red 3.8%, red 19.8%, transparent 19.8%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row1_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.0%, red 5.0%, red 19.7%, transparent 19.7%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row1_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 31.8%, red 31.8%, red 36.8%, transparent 36.8%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 37.9%, transparent 37.9%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 91.1%, green 91.1%, green 100.0%, transparent 100.0%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row2_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 7.0%, transparent 7.0%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.9%, red 0.9%, red 1.0%, transparent 1.0%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, red 50.0%, red 59.7%, transparent 59.7%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 13.5%, green 13.5%, green 15.3%, transparent 15.3%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 9.5%, red 9.5%, red 19.8%, transparent 19.8%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row2_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 9.2%, red 9.2%, red 19.7%, transparent 19.7%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row2_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 19.7%, red 19.7%, red 36.8%, transparent 36.8%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.9%, green 37.9%, green 50.0%, transparent 50.0%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 91.1%, green 91.1%, green 100.0%, transparent 100.0%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row3_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 7.0%, green 7.0%, green 20.0%, transparent 20.0%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 1.0%, green 1.0%, green 1.1%, transparent 1.1%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 59.7%, green 59.7%, green 70.1%, transparent 70.1%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 13.5%, green 13.5%, green 17.9%, transparent 17.9%);
#         }    #T_d04c14b0_57f4_11ea_9e41_507b9d42aeb2row3_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 19.2%, red 19.2%, red 19.8%, transparent 19.8%);

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Linear Regression

# %%
# lets do the Modelling

# It is a Regression Problem

# linear Regression
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

print("Training Accuracy :", model.score(x_train, y_train))
print("Testing Accuracy :", model.score(x_test, y_test))
# Out:
# Training Accuracy : 0.9999845250297132
# Testing Accuracy : 0.9452800682648794

# %%
# checking the accuracy of the model

from sklearn.metrics import mean_squared_error

error = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(error)
print(rmse)
# Out:
# 1232.65496084432

# %%
# lets check the r2 score of the model

from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.9452800682648794

# %%
# lets check the mean, median, standard deviation etc of the predictions

print("Mean of the Predictions :", y_pred.mean())
print("Maxima of the Predictions :",y_pred.max())
print("Minima of the Predictions :",y_pred.min())
print("Standard Deviation of the Predictions :", y_pred.std())

pred = pd.DataFrame(y_pred)
print("Median of the Predictions :",pred.median())
# Out:
# Mean of the Predictions : 10757.057518723434
# Maxima of the Predictions : 32031.031156659483
# Minima of the Predictions : 4497.16330965962
# Standard Deviation of the Predictions : 5078.804896407288
# Median of the Predictions : 0    9397.006005
# dtype: float64

# %%
pred.style.bar(color = 'orange', align = 'mid')
# Out:
# <style  type="text/css" >
#     #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 25.7%, transparent 25.7%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 23.6%, transparent 23.6%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 29.3%, transparent 29.3%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 37.4%, transparent 37.4%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 30.3%, transparent 30.3%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 20.8%, transparent 20.8%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 29.8%, transparent 29.8%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 43.5%, transparent 43.5%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 100.0%, transparent 100.0%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 20.0%, transparent 20.0%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 61.4%, transparent 61.4%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 24.2%, transparent 24.2%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 62.4%, transparent 62.4%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 14.0%, transparent 14.0%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 22.5%, transparent 22.5%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 30.2%, transparent 30.2%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row16_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 31.9%, transparent 31.9%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row17_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 40.1%, transparent 40.1%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row18_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 57.8%, transparent 57.8%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row19_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 24.5%, transparent 24.5%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row20_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 21.9%, transparent 21.9%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row21_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 26.0%, transparent 26.0%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row22_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 20.2%, transparent 20.2%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row23_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 24.0%, transparent 24.0%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row24_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 18.3%, transparent 18.3%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row25_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 28.6%, transparent 28.6%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row26_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 19.2%, transparent 19.2%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row27_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 22.6%, transparent 22.6%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row28_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 45.3%, transparent 45.3%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row29_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 29.9%, transparent 29.9%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row30_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 38.2%, transparent 38.2%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row31_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 20.5%, transparent 20.5%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row32_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 66.7%, transparent 66.7%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row33_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 18.1%, transparent 18.1%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row34_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 59.3%, transparent 59.3%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row35_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 35.2%, transparent 35.2%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row36_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 26.7%, transparent 26.7%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row37_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 25.1%, transparent 25.1%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row38_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 31.5%, transparent 31.5%);
#         }    #T_e425385c_57f4_11ea_a6fa_507b9d42aeb2row39_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 14.4%, transparent 14.4%);
#         }    #T_e425385c_57f4_1

# %% [markdown]
# ## Real Time Prediction

# %%
df.head()
# Out:
#    year  road  seasonalimpact demand  wttons  labour  toll  distance  \
# 0  2013     2               1      2    10.0     750  8200    1460.0
# 1  2013     2               1      2    14.8    1110  8600    1360.0
# 2  2013     2               1      2    12.0     900  8300    1310.0
# 3  2013     2               1      2    10.0     750  2400     650.0
# 4  2013     2               1      2     8.0     600  3500     560.0
#
#    fuelcost  miscellaneous  tariff
# 0     23534         9000.0   17950
# 1     22184        10000.0   19710
# 2     21476         9400.0   18600
# 3     10473         6000.0    9150
# 4      9417         5600.0    9700

# %% [raw]
# The Values for which we want to predict the Tariff Rates
#
# year = 2015
# road = 2
# seasonalimpact = 1
# demand = 2
# wttons = 10.0
# labour = 750
# toll = 7200
# distance = 1500.0
# fuelcost = 25000
# miscellaneous = 9000.0

# %%
# inverse transforming the values
prediction = model.predict(sc.transform(np.array([[2015, 2, 1, 2, 10.0, 750, 7200, 1500.0, 25000, 9000.0]])))

# %%
prediction
# Out:
# array([16869.53358645])

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

print("Training Accuracy :", model.score(x_train, y_train))
print("Testing Accuracy :", model.score(x_test, y_test))
# Out:
# Training Accuracy : 1.0
# Testing Accuracy : 0.9047223064198067

# %%
# checking the accuracy of the model

from sklearn.metrics import mean_squared_error

error = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(error)
print(rmse)
# Out:
# 1626.538592565036

# %%
# lets check the r2 score of the model

from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.9047223064198067

# %%
# lets check the mean, median, standard deviation etc of the predictions

print("Mean of the Predictions :", y_pred.mean())
print("Maxima of the Predictions :",y_pred.max())
print("Minima of the Predictions :",y_pred.min())
print("Standard Deviation of the Predictions :", y_pred.std())

pred = pd.DataFrame(y_pred)
print("Median of the Predictions :",pred.median())
# Out:
# Mean of the Predictions : 10623.913793103447
# Maxima of the Predictions : 23205.0
# Minima of the Predictions : 4590.0
# Standard Deviation of the Predictions : 4597.47688781006
# Median of the Predictions : 0    9331.0
# dtype: float64

# %% [markdown]
# ## Support Vector Regressor

# %%
from sklearn.svm import SVR

model = SVR()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

print("Training Accuracy :", model.score(x_train, y_train))
print("Testing Accuracy :", model.score(x_test, y_test))
# Out:
# Training Accuracy : -0.06312443426739778
# Testing Accuracy : -0.046509864717476423

# %%
# checking the accuracy of the model

from sklearn.metrics import mean_squared_error

error = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(error)
print(rmse)
# Out:
# 5390.641093541672

# %%
# lets check the r2 score of the model

from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# -0.046509864717476423

# %%
# lets check the mean, median, standard deviation etc of the predictions

print("Mean of the Predictions :", y_pred.mean())
print("Maxima of the Predictions :",y_pred.max())
print("Minima of the Predictions :",y_pred.min())
print("Standard Deviation of the Predictions :", y_pred.std())

pred = pd.DataFrame(y_pred)
print("Median of the Predictions :",pred.median())
# Out:
# Mean of the Predictions : 9381.917710650067
# Maxima of the Predictions : 9423.498194452006
# Minima of the Predictions : 9346.400811195508
# Standard Deviation of the Predictions : 24.619384171167773
# Median of the Predictions : 0    9375.242143
# dtype: float64

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators = 500, max_depth = 50)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

print("Training Accuracy :", model.score(x_train, y_train))
print("Testing Accuracy :", model.score(x_test, y_test))
# Out:
# Training Accuracy : 0.9970662124529847
# Testing Accuracy : 0.8989438325671315

# %%
# checking the accuracy of the model

from sklearn.metrics import mean_squared_error

error = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(error)
print(rmse)
# Out:
# 1675.136363071027

# %%
# lets check the r2 score of the model

from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.8989438325671315

# %%
# lets check the mean, median, standard deviation etc of the predictions

print("Mean of the Predictions :", y_pred.mean())
print("Maxima of the Predictions :",y_pred.max())
print("Minima of the Predictions :",y_pred.min())
print("Standard Deviation of the Predictions :", y_pred.std())

pred = pd.DataFrame(y_pred)
print("Median of the Predictions :",pred.median())
# Out:
# Mean of the Predictions : 10570.791137931037
# Maxima of the Predictions : 22019.288
# Minima of the Predictions : 4639.636
# Standard Deviation of the Predictions : 4450.146105639154
# Median of the Predictions : 0    9238.261
# dtype: float64

# %% [markdown]
# ## Model Explanation

# %%
# lets import the required libraries

import eli5
from eli5.sklearn import PermutationImportance
# Out:
# Using TensorFlow backend.
# c:\users\roshan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:493: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# c:\users\roshan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:494: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# c:\users\roshan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:495: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# c:\users\roshan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:496: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# c:\users\roshan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:497: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# c:\users\roshan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:502: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.

# %%
# lets create a model for Permutation Importance
perm = PermutationImportance(model, random_state = 0)

# lets fit the test data to the model
perm.fit(x_test, y_test)

# lets specify the feature names
features = data.columns[:-1].tolist()

# lets check the weights of the features in predictive modelling
plt.rcParams['figure.figsize'] = (10, 15)
eli5.show_weights(perm, feature_names = features)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.5591
#
#                     &plusmn; 0.1982
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 toll
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.21%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2015
#
#                     &plusmn; 0.0510
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 miscellaneous
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.93%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0385
#
#                     &plusmn; 0.0102
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 labour
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.32%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0162
#
#                     &plusmn; 0.0035
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 fuelcost
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.22%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0054
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 distance
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.86%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0005
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 wttons
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.89%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 road
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.99%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 year
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 seasonalimpact
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.98%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0000
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 demand
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>
